# %%
import os
import sys
import random
import math
import re
import time
import numpy as np
import cv2
import matplotlib
import matplotlib.pyplot as plt
import skimage
import tensorflow as tf
import imgaug_slices as im
import slices
import slices_config


# Root directory of the project
ROOT_DIR = os.path.abspath("../")
# Data directory
DATA_DIR = os.path.join(ROOT_DIR, "database")
# Train directory
TRAIN_DIR = os.path.join(DATA_DIR, "train")
# Validate directory
VAL_DIR = os.path.join(DATA_DIR, "validate")
# Import Mask RCNN
sys.path.append(ROOT_DIR)  # To find local version of the library
from mrcnn.config import Config
from mrcnn import utils
import mrcnn.model as modellib
from mrcnn import visualize
from mrcnn.model import log

# Directory to save logs and trained model
config = slices_config.Config1()
MODEL_DIR = os.path.join(os.path.join(ROOT_DIR, "logs"),"Config1_all")
if not os.path.exists(MODEL_DIR):
    os.makedirs(MODEL_DIR)
# Local path to trained weights file
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")
# Download COCO trained weights from Releases if needed
if not os.path.exists(COCO_MODEL_PATH):
    utils.download_trained_weights(COCO_MODEL_PATH)
# Out:
# Using TensorFlow backend.

# %%
def get_ax(rows=1, cols=1, size=8):
    """Return a Matplotlib Axes array to be used in
    all visualizations in the notebook. Provide a
    central point to control graph sizes.
    
    Change the default size attribute to control the size
    of rendered images
    """
    _, ax = plt.subplots(rows, cols, figsize=(size*cols, size*rows))
    return ax

# %%
config = slices_config.Config1()

# %%
config.BATCH_SIZE = 1
config.IMAGES_PER_GPU = 1

# %%
dataset_train = slices.SlicesDataset()
dataset_val = slices.SlicesDataset()

# %%
channels = ['base','mf']

# %%
dataset_train.load_slices(TRAIN_DIR, 3, 40, channels = channels)
dataset_train.prepare()
dataset_val.load_slices(VAL_DIR, 3, 10, channels = channels)
dataset_val.prepare()
# Out:
# processing: image 0
# processing: image 1
# processing: image 2
# processing: image 0
# processing: image 1
# processing: image 2

# %%
mean_pixels = np.zeros(len(channels))
for image_id in dataset_train.image_ids:
    image = dataset_train.load_image(image_id)
    for n in range(len(channels)):
        mean_pixels[n]+= np.mean(image[:,:,n])
mean_pixels = mean_pixels/len(dataset_train.image_ids)
config.MEAN_PIXEL = mean_pixels

# %%
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  512
# IMAGE_META_SIZE                15
# IMAGE_MIN_DIM                  512
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [512 512   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [144.53343108   2.60146166  20.55693239]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           Config1
# NUM_CLASSES                    3
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.5
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (80, 120, 160, 200, 240)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                100
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               10
# WEIGHT_DECAY                   0.0001

# %%
# Create model in training mode
model = modellib.MaskRCNN(mode = "inference", 
                          config = config,
                          model_dir = MODEL_DIR)
MODEL_PATH = os.path.join(MODEL_DIR, "mask_rcnn_slices.h5")
print("Loading weights from ", MODEL_PATH)
model.load_weights(MODEL_PATH, by_name=True)
# Out:
# Loading weights from  C:\Users\Utente\Desktop\slices_segmentation\logs\Config1_all\mask_rcnn_slices.h5

# %%
# Test on a random image
# image_id = random.choice(dataset_val.image_ids)
image_id = 27
original_image, image_meta, gt_class_id, gt_bbox, gt_mask =\
    modellib.load_image_gt(dataset_val, config, 
                           image_id, use_mini_mask=False)

log("original_image", original_image)
log("image_meta", image_meta)
log("gt_class_id", gt_class_id)
log("gt_bbox", gt_bbox)
log("gt_mask", gt_mask)

visualize.display_instances(original_image, gt_bbox, gt_mask, gt_class_id, 
                            dataset_train.class_names, figsize=(8, 8))
# Out:
# original_image           shape: (512, 512, 3)         min:    0.00000  max:  238.00000  uint8
# image_meta               shape: (15,)                 min:    0.00000  max:  512.00000  int32
# gt_class_id              shape: (11,)                 min:    1.00000  max:    2.00000  int32
# gt_bbox                  shape: (11, 4)               min:    0.00000  max:  512.00000  int32
# gt_mask                  shape: (512, 512, 11)        min:    0.00000  max:    1.00000  bool

# %%
dataset_val.image_info[image_id]
# Out:
# {'id': 27,
#  'source': 'slices',
#  'path': 'C:\\Users\\Utente\\Desktop\\slices_segmentation\\database\\validate\\image_2\\patch_10_8',
#  'width': 512,
#  'height': 512,
#  'channels': ['base', 'edge', 'mf']}

# %%
results = model.detect([original_image], verbose=1)

r = results[0]
visualize.display_instances(original_image, r['rois'], r['masks'], r['class_ids'], 
                    dataset_val.class_names, r['scores'], ax=get_ax())
# Out:
# Processing 1 images
# image                    shape: (512, 512, 3)         min:    0.00000  max:  238.00000  uint8
# molded_images            shape: (1, 512, 512, 3)      min: -118.53343  max:  214.44307  float64
# image_metas              shape: (1, 15)               min:    0.00000  max:  512.00000  int32
# anchors                  shape: (1, 65472, 4)         min:   -0.33210  max:    1.21413  float32
